# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Ishikaaa/ML_Assignment-1/blob/master/ML_Ass4(pandas1).ipynb)

# %%
#Q1.
import pandas as pd 
import numpy as np 
df=pd.DataFrame(
    {"Name":['Ishika Garg','Aman'],
     'Age':[18,19],
     'mail_id':['gargishika1998@gmail.com','aman19@gmail.com'],
     'phone_number':['8688686866','6866686866']}
   )
print(df)
n=len(df.index)
# Out:
#    Age         Name                   mail_id phone_number
# 0   18  Ishika Garg  gargishika1998@gmail.com   8688686866
# 1   19         Aman          aman19@gmail.com   6866686866

# %%
#adding data to dataframe 
print(n)
a=input("enter your name=")
b=int(input("Enter your age="))
c=input("Enter your mail id=")
d=input("Enter your phone number=")
df.loc[n]=[a,b,c,d]
print(df)
# Out:
# 2
# enter your name=raman
# Enter your age=12
# Enter your mail id=raman12@gmail.com
# Enter your phone number=1111111111
#       Age         Name                   mail_id phone_number
# 0      18  Ishika Garg  gargishika1998@gmail.com   8688686866
# 1      19         Aman          aman19@gmail.com   6866686866
# 2  raman            12         raman12@gmail.com   1111111111

# %%
#importing dataset
df1=pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")
print(df1)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5     11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6     11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7     11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9    11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
# 10   11/11/2007  Canberra      9.1     25.2       0.0          4.2      11.9
# ...

# %%
#first 5 rows of a dataframe 
df1.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#first 10 rows of a dataframe 
df1.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
#statistics of Mintemp
df1['MinTemp'].describe()
# Out:
# count    366.000000
# mean       7.265574
# std        6.025800
# min       -5.300000
# 25%        2.300000
# 50%        7.450000
# 75%       12.500000
# max       20.900000
# Name: MinTemp, dtype: float64

# %%
#statistics of Maxtemp
df1['MaxTemp'].describe()
# Out:
# count    366.000000
# mean      20.550273
# std        6.690516
# min        7.600000
# 25%       15.025000
# 50%       19.650000
# 75%       25.500000
# max       35.800000
# Name: MaxTemp, dtype: float64

# %%
#last 5 rows of a dataframe 
df1.tail()
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
#Extract column from a dataset 
s1=df1['Evaporation']
print("*"*50+"EVAPORATION"+"*"*50)
print(s1)
#applying statistics on s1
print("*"*50+"APPLYING STATISTICS"+"*"*50)
s1.describe()
# Out:
# **************************************************EVAPORATION**************************************************
# 0       3.4
# 1       4.4
# 2       5.8
# 3       7.2
# 4       5.6
# 5       5.8
# 6       4.2
# 7       5.6
# 8       4.0
# 9       5.4
# 10      4.2
# 11      7.2
# 12      7.2
# 13      6.2
# 14      8.8
# 15      8.4
# 16      7.2
# 17      7.2
# 18      7.4
# 19      8.0
# 20      8.8
# 21      9.2
# 22      2.8
# 23      1.2
# 24      4.4
# 25      6.8
# 26      6.6
# 27      4.4
# 28      7.0
# 29      2.6
#        ...
# 336     5.2
# 337    10.0
# 338     9.4
# 339     4.2
# 340     4.8
# 341     5.4
# 342     5.8
# 343     6.2
# 344     4.4
# 345     5.4
# 346     4.8
# 347     6.2
# 348     6.6
# 349     3.4
# 350     4.2
# 351     6.2
# 352     5.4
# 353     5.8
# 354     7.6
# 355     9.0
# 356     4.8
# 357     7.4
# 358     5.4
# 359     5.2
# 360     6.8
# 361     7.6
# 362    11.6
# 363     8.4
# 364     5.0
# 365     6.0
# ...

# %%
#Extract column from a dataset 
s2=df1['Temp9am']
print("*"*50+"TEMP9AM"+"*"*50)
print(s2)
#applying statistics on s1
print("*"*50+"APPLYING STATISTICS"+"*"*50)
s1.describe()
# Out:
# **************************************************TEMP9AM**************************************************
# 0      14.4
# 1      17.5
# 2      15.4
# 3      13.5
# 4      11.1
# 5      10.9
# 6      12.4
# 7      12.1
# 8      14.1
# 9      13.3
# 10     14.6
# 11     16.8
# 12     17.0
# 13     19.7
# 14     18.7
# 15     19.1
# 16     20.2
# 17     20.1
# 18     20.2
# 19     22.8
# 20     22.2
# 21     16.5
# 22     14.0
# 23     17.8
# 24     16.8
# 25     19.8
# 26     16.5
# 27     18.8
# 28     18.9
# 29     17.3
#        ...
# 336    19.0
# 337    22.5
# 338    14.5
# 339    11.7
# 340    12.8
# 341     6.9
# 342     7.2
# 343     8.1
# 344    10.0
# 345    13.6
# 346    12.6
# 347    16.3
# 348    14.5
# 349    11.6
# 350     9.6
# 351    11.6
# 352    12.7
# 353    16.8
# 354    16.4
# 355    11.4
# 356     8.3
# 357     9.1
# 358     9.4
# 359    12.0
# 360    16.3
# 361    20.4
# 362    17.2
# 363    14.5
# 364    15.8
# 365    23.8
# ...

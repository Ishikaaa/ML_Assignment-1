# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Ishikaaa/ML_Assignment-1/blob/master/ML_Assignment--5.ipynb)

# %%
import pandas as pd 
#Q1.
aa={'name':['Ishika Garg','Pishika'],
  'age':['18','19'],
  'mail_id':['gargishika1998@gmail.com','pishika1999@gmail.com'],
  'phone_number':['8686868688','6868686866']
}
a=pd.DataFrame(aa)
print(a)
ab=str(input("Enter name="))
b=str(input("Enter age="))
c=str(input("Enter mail id="))
d=str(input("Enter phone number="))
aaa=pd.DataFrame({'name':ab,
  'age':b,
  'mail_id':c,
  'phone_number':d
})
frames=[aa,aaa]
result = pd.concat(frames)
print(result)
# Out:
#   age                   mail_id         name phone_number
# 0  18  gargishika1998@gmail.com  Ishika Garg   8686868688
# 1  19     pishika1999@gmail.com      Pishika   6868686866
# Enter name=alert
# Enter age=20
# Enter mail id=alert20@gmail.com
# Enter phone number=8888888888
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-19adb3a97944> in <module>()
#      15   'age':b,
#      16   'mail_id':c,
# ---> 17   'phone_number':d
#      18 })
#      19 frames=[aa,aaa]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
# ...

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1f92xSdbSedDbtZnD_Y5a_rbNG97kJL7v'
data = drive.CreateFile({'id': file_id})

# %%
import io 
import pandas as pd
df=pd.read_csv(io.StringIO(data.GetContentString()))
print(df.head())
print("*"*100)
print(df.head(10))
print("*"*100)
print(df.head().describe())
print("*"*100)
print(df.tail())
print("*"*100)
print(df.head(2).describe())
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...
